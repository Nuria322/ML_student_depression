# %% [markdown]
# # Modelo No Supervisado de ML

# %% [markdown]
# ### Librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture # Modelo que entrena al azar con distribucion gausiana
from sklearn.cluster import SpectralClustering

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_csv(r'C:\Users\nuria\OneDrive\Escritorio\ML_student_depression\data\processed\dataset_limpio_FE.csv')
df.head()
# Out:
#          id  Gender   Age  City  Profession  Academic Pressure  Work Pressure  \
# 0  0.000000       1  0.60    51          11                1.0            0.0
# 1  0.000043       0  0.24     3          11                0.4            0.0
# 2  0.000171       1  0.52    44          11                0.6            0.0
# 3  0.000199       0  0.40    49          11                0.6            0.0
# 4  0.000213       0  0.28    16          11                0.8            0.0
#
#        CGPA  Study Satisfaction  Job Satisfaction  ...  \
# 0  0.588000                 0.4               0.0  ...
# 1  0.062442                 1.0               0.0  ...
# 2  0.062442                 1.0               0.0  ...
# 3  0.062442                 0.4               0.0  ...
# 4  0.252000                 0.6               0.0  ...
#
#    Profession_Digital Marketer  Profession_Doctor  \
# 0                            0                  0
# 1                            0                  0
# ...

# %%
X = df.drop(columns=["Depression"])
y =df["Depression"]

# %%
sc2 = SpectralClustering(n_clusters=2, gamma=1, random_state=42)
sc2.fit(X)

# %%
dbscan = DBSCAN(eps=0.05, min_samples=5) # eps es la distancia máxima entre dos puntos, en este caso 0.05
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.05)

# %%
df.head()
# Out:
#          id  Gender   Age  City  Profession  Academic Pressure  Work Pressure  \
# 0  0.000000       1  0.60    51          11                1.0            0.0
# 1  0.000043       0  0.24     3          11                0.4            0.0
# 2  0.000171       1  0.52    44          11                0.6            0.0
# 3  0.000199       0  0.40    49          11                0.6            0.0
# 4  0.000213       0  0.28    16          11                0.8            0.0
#
#        CGPA  Study Satisfaction  Job Satisfaction  ...  \
# 0  0.588000                 0.4               0.0  ...
# 1  0.062442                 1.0               0.0  ...
# 2  0.062442                 1.0               0.0  ...
# 3  0.062442                 0.4               0.0  ...
# 4  0.252000                 0.6               0.0  ...
#
#    Profession_Digital Marketer  Profession_Doctor  \
# 0                            0                  0
# 1                            0                  0
# ...

# %% [markdown]
# ## TERMINAR!!

# %%
from sklearn.mixture import GaussianMixture # Modelo que entrena al azar con distribucion gausiana

y_pred = GaussianMixture(n_components=3, random_state=42).fit(X).predict(X)

mapping = {}
for class_id in np.unique(y):
    mode, _ = stats.mode(y_pred[y==class_id])
    mapping[mode] = class_id

y_pred = np.array([mapping[cluster_id] for cluster_id in y_pred])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 10
#       7     mode, _ = stats.mode(y_pred[y==class_id])
#       8     mapping[mode] = class_id
# ---> 10 y_pred = np.array([mapping[cluster_id] for cluster_id in y_pred])
#
# Cell In[53], line 10, in <listcomp>(.0)
#       7     mode, _ = stats.mode(y_pred[y==class_id])
#       8     mapping[mode] = class_id
# ---> 10 y_pred = np.array([mapping[cluster_id] for cluster_id in y_pred])
#
# KeyError: np.int64(1)

# %%
from sklearn.mixture import GaussianMixture

# Assuming X is your feature data (2D array or DataFrame)
# Train the model
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(X)

# Predict cluster labels for the data in X
y_pred = gmm.predict(X)

# Now y_pred contains the predicted cluster labels

# %%
(y_pred==y).sum() / len(y_pred)
# Out:
# np.float64(0.23633561521092433)
