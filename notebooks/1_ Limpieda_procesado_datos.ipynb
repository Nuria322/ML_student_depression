# %% [markdown]
# # Limpieza y procesado de datos

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (0.5.2)
# Requirement already satisfied: scipy in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from missingno) (1.15.2)
# Requirement already satisfied: numpy in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from missingno) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from missingno) (3.10.0)
# Requirement already satisfied: seaborn in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\nuria\onedrive\escritorio\ml_student_depression\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from missingno import matrix
import missingno as msno

# %%
df1 = pd.read_csv(r'C:\Users\nuria\OneDrive\Escritorio\ML_student_depression\data\raw\Student Depression Dataset.csv')
df1.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# 3          7-8 hours       Moderate      BCA
# 4          5-6 hours       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# 1                                    No               3.0               2.0
# 2                                    No               9.0               1.0
# 3                                   Yes               4.0               5.0
# 4                                   Yes               1.0               1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
df2 = df1.set_index('id')
df2.head(3)
# Out:
#     Gender   Age           City Profession  Academic Pressure  Work Pressure  \
# id
# 2     Male  33.0  Visakhapatnam    Student                5.0            0.0
# 8   Female  24.0      Bangalore    Student                2.0            0.0
# 26    Male  31.0       Srinagar    Student                3.0            0.0
#
#     CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# id
# 2   8.97                 2.0               0.0          5-6 hours
# 8   5.90                 5.0               0.0          5-6 hours
# 26  7.03                 5.0               0.0  Less than 5 hours
#
#    Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# id
# 2         Healthy  B.Pharm                                   Yes
# 8        Moderate      BSc                                    No
# 26        Healthy       BA                                    No
#
#     Work/Study Hours  Financial Stress Family History of Mental Illness  \
# id
# 2                3.0               1.0                               No
# 8                3.0               2.0                              Yes
# 26               9.0               1.0                              Yes
#
#     Depression
# id
# 2            1
# 8            0
# 26           0

# %% [markdown]
# ### Opciones
# - Eliminar la columna 'City'
# - Numerar las columnas 'Sleep Duration' y 'Dietary habits'
# - Convertir los yes y no en 0 y 1

# %%
df2.drop('City')
df2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df2.drop('City')
#       2 df2.head()
#
# File c:\Users\nuria\OneDrive\Escritorio\ML_student_depression\.venv\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\nuria\OneDrive\Escritorio\ML_student_depression\.venv\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\nuria\OneDrive\Escritorio\ML_student_depression\.venv\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\nuria\OneDrive\Escritorio\ML_student_depression\.venv\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['City'] not found in axis"
